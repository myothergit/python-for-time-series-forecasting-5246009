# %% [markdown]
# # Join and preprocess multiple time series data

# %% [markdown]
# ## Load data

# %%
import pandas as pd

path = '../../data/FRED/CORESTICKM159SFRBATL.csv'
df1 = pd.read_csv(path, index_col=0, parse_dates=True)

path = '../../data/FRED/UNRATE.csv'
df2 = pd.read_csv(path, index_col=0, parse_dates=True)

path = '../../data/FRED/FEDFUNDS.csv'
df3 = pd.read_csv(path, index_col=0, parse_dates=True)

path = '../../data/FRED/T10YIE.csv'
df4 = pd.read_csv(path, index_col=0, parse_dates=True)

# %% [markdown]
# ## Join data

# %% [markdown]
# ### Inner join

# %%
df = pd.concat([df1, df2, df3, df4], axis=1, join='inner')
df
# Out:
#                   CORESTICKM159SFRBATL  UNRATE  FEDFUNDS  T10YIE
# observation_date
# 2020-05-01                    2.000025    13.2      0.05    1.06
# 2020-06-01                    1.998261    11.0      0.08    1.18
# ...                                ...     ...       ...     ...
# 2024-11-01                    3.876177     4.2      4.64    2.33
# 2025-01-01                    3.625276     4.0      4.33     NaN
#
# [43 rows x 4 columns]

# %%
import plotly.io as pio
pio.templates.default = "plotly_dark"

pd.options.plotting.backend = "plotly"

# %%
fig = df.plot(title="FRED Data", width=1000, height=500)
fig.update_layout(hovermode="x unified")

# %%
df1.loc['2025']
# Out:
#                   CORESTICKM159SFRBATL
# observation_date
# 2025-01-01                    3.625276
# 2025-02-01                    3.516515
# 2025-03-01                    3.257815

# %%
df2.loc['2025']
# Out:
#                   UNRATE
# observation_date
# 2025-01-01           4.0
# 2025-02-01           4.1
# 2025-03-01           4.2

# %%
df3.loc['2025']
# Out:
#                   FEDFUNDS
# observation_date
# 2025-01-01            4.33
# 2025-02-01            4.33
# 2025-03-01            4.33

# %%
df4.loc['2025'].style.format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8c1ea">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8c1ea_level0_col0" class="col_heading level0 col0" >T10YIE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >observation_date</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c1ea_level0_row0" class="row_heading level0 row0" >2025-01-01 00:00:00</th>
#       <td id="T_8c1ea_row0_col0" class="data row0 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row1" class="row_heading level0 row1" >2025-01-02 00:00:00</th>
#       <td id="T_8c1ea_row1_col0" class="data row1 col0" >2.34</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row2" class="row_heading level0 row2" >2025-01-03 00:00:00</th>
#       <td id="T_8c1ea_row2_col0" class="data row2 col0" >2.34</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row3" class="row_heading level0 row3" >2025-01-06 00:00:00</th>
#       <td id="T_8c1ea_row3_col0" class="data row3 col0" >2.34</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row4" class="row_heading level0 row4" >2025-01-07 00:00:00</th>
#       <td id="T_8c1ea_row4_col0" class="data row4 col0" >2.38</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row5" class="row_heading level0 row5" >2025-01-08 00:00:00</th>
#       <td id="T_8c1ea_row5_col0" class="data row5 col0" >2.40</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row6" class="row_heading level0 row6" >2025-01-09 00:00:00</th>
#       <td id="T_8c1ea_row6_col0" class="data row6 col0" >2.39</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row7" class="row_heading level0 row7" >2025-01-10 00:00:00</th>
#       <td id="T_8c1ea_row7_col0" class="data row7 col0" >2.43</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row8" class="row_heading level0 row8" >2025-01-13 00:00:00</th>
#       <td id="T_8c1ea_row8_col0" class="data row8 col0" >2.45</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row9" class="row_heading level0 row9" >2025-01-14 00:00:00</th>
#       <td id="T_8c1ea_row9_col0" class="data row9 col0" >2.44</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row10" class="row_heading level0 row10" >2025-01-15 00:00:00</th>
#       <td id="T_8c1ea_row10_col0" class="data row10 col0" >2.42</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row11" class="row_heading level0 row11" >2025-01-16 00:00:00</th>
#       <td id="T_8c1ea_row11_col0" class="data row11 col0" >2.42</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row12" class="row_heading level0 row12" >2025-01-17 00:00:00</th>
#       <td id="T_8c1ea_row12_col0" class="data row12 col0" >2.41</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row13" class="row_heading level0 row13" >2025-01-20 00:00:00</th>
#       <td id="T_8c1ea_row13_col0" class="data row13 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row14" class="row_heading level0 row14" >2025-01-21 00:00:00</th>
#       <td id="T_8c1ea_row14_col0" class="data row14 col0" >2.38</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row15" class="row_heading level0 row15" >2025-01-22 00:00:00</th>
#       <td id="T_8c1ea_row15_col0" class="data row15 col0" >2.40</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row16" class="row_heading level0 row16" >2025-01-23 00:00:00</th>
#       <td id="T_8c1ea_row16_col0" class="data row16 col0" >2.42</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row17" class="row_heading level0 row17" >2025-01-24 00:00:00</th>
#       <td id="T_8c1ea_row17_col0" class="data row17 col0" >2.43</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row18" class="row_heading level0 row18" >2025-01-27 00:00:00</th>
#       <td id="T_8c1ea_row18_col0" class="data row18 col0" >2.40</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row19" class="row_heading level0 row19" >2025-01-28 00:00:00</th>
#       <td id="T_8c1ea_row19_col0" class="data row19 col0" >2.42</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row20" class="row_heading level0 row20" >2025-01-29 00:00:00</th>
#       <td id="T_8c1ea_row20_col0" class="data row20 col0" >2.40</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row21" class="row_heading level0 row21" >2025-01-30 00:00:00</th>
#       <td id="T_8c1ea_row21_col0" class="data row21 col0" >2.38</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row22" class="row_heading level0 row22" >2025-01-31 00:00:00</th>
#       <td id="T_8c1ea_row22_col0" class="data row22 col0" >2.42</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row23" class="row_heading level0 row23" >2025-02-03 00:00:00</th>
#       <td id="T_8c1ea_row23_col0" class="data row23 col0" >2.45</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row24" class="row_heading level0 row24" >2025-02-04 00:00:00</th>
#       <td id="T_8c1ea_row24_col0" class="data row24 col0" >2.44</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row25" class="row_heading level0 row25" >2025-02-05 00:00:00</th>
#       <td id="T_8c1ea_row25_col0" class="data row25 col0" >2.42</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row26" class="row_heading level0 row26" >2025-02-06 00:00:00</th>
#       <td id="T_8c1ea_row26_col0" class="data row26 col0" >2.42</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row27" class="row_heading level0 row27" >2025-02-07 00:00:00</th>
#       <td id="T_8c1ea_row27_col0" class="data row27 col0" >2.42</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row28" class="row_heading level0 row28" >2025-02-10 00:00:00</th>
#       <td id="T_8c1ea_row28_col0" class="data row28 col0" >2.44</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row29" class="row_heading level0 row29" >2025-02-11 00:00:00</th>
#       <td id="T_8c1ea_row29_col0" class="data row29 col0" >2.46</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row30" class="row_heading level0 row30" >2025-02-12 00:00:00</th>
#       <td id="T_8c1ea_row30_col0" class="data row30 col0" >2.46</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row31" class="row_heading level0 row31" >2025-02-13 00:00:00</th>
#       <td id="T_8c1ea_row31_col0" class="data row31 col0" >2.44</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row32" class="row_heading level0 row32" >2025-02-14 00:00:00</th>
#       <td id="T_8c1ea_row32_col0" class="data row32 col0" >2.43</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row33" class="row_heading level0 row33" >2025-02-17 00:00:00</th>
#       <td id="T_8c1ea_row33_col0" class="data row33 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row34" class="row_heading level0 row34" >2025-02-18 00:00:00</th>
#       <td id="T_8c1ea_row34_col0" class="data row34 col0" >2.45</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row35" class="row_heading level0 row35" >2025-02-19 00:00:00</th>
#       <td id="T_8c1ea_row35_col0" class="data row35 col0" >2.45</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row36" class="row_heading level0 row36" >2025-02-20 00:00:00</th>
#       <td id="T_8c1ea_row36_col0" class="data row36 col0" >2.45</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row37" class="row_heading level0 row37" >2025-02-21 00:00:00</th>
#       <td id="T_8c1ea_row37_col0" class="data row37 col0" >2.42</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row38" class="row_heading level0 row38" >2025-02-24 00:00:00</th>
#       <td id="T_8c1ea_row38_col0" class="data row38 col0" >2.42</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row39" class="row_heading level0 row39" >2025-02-25 00:00:00</th>
#       <td id="T_8c1ea_row39_col0" class="data row39 col0" >2.38</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row40" class="row_heading level0 row40" >2025-02-26 00:00:00</th>
#       <td id="T_8c1ea_row40_col0" class="data row40 col0" >2.36</td>
#     </tr>
#     <tr>
#       <th id="T_8c1ea_level0_row41" class="row_heading level0 row41" >2025-02-27 00:00:00</th>
#       <td id="T_8c1ea_row41_col0" class="data row41 col0" >2.37</td>
#     </tr>
#     <tr>

# %% [markdown]
# ### Outer join

# %%
df = pd.concat([df1, df2, df3, df4], axis=1, join='outer', sort=True)
df
# Out:
#                   CORESTICKM159SFRBATL  UNRATE  FEDFUNDS  T10YIE
# observation_date
# 1948-01-01                         NaN     3.4       NaN     NaN
# 1948-02-01                         NaN     3.8       NaN     NaN
# ...                                ...     ...       ...     ...
# 2025-04-10                         NaN     NaN       NaN    2.19
# 2025-04-11                         NaN     NaN       NaN    2.20
#
# [2189 rows x 4 columns]

# %%
df.loc['2025'].style.format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_fd227">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd227_level0_col0" class="col_heading level0 col0" >CORESTICKM159SFRBATL</th>
#       <th id="T_fd227_level0_col1" class="col_heading level0 col1" >UNRATE</th>
#       <th id="T_fd227_level0_col2" class="col_heading level0 col2" >FEDFUNDS</th>
#       <th id="T_fd227_level0_col3" class="col_heading level0 col3" >T10YIE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >observation_date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd227_level0_row0" class="row_heading level0 row0" >2025-01-01 00:00:00</th>
#       <td id="T_fd227_row0_col0" class="data row0 col0" >3.63</td>
#       <td id="T_fd227_row0_col1" class="data row0 col1" >4.00</td>
#       <td id="T_fd227_row0_col2" class="data row0 col2" >4.33</td>
#       <td id="T_fd227_row0_col3" class="data row0 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_fd227_level0_row1" class="row_heading level0 row1" >2025-01-02 00:00:00</th>
#       <td id="T_fd227_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_fd227_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_fd227_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_fd227_row1_col3" class="data row1 col3" >2.34</td>
#     </tr>
#     <tr>
#       <th id="T_fd227_level0_row2" class="row_heading level0 row2" >2025-01-03 00:00:00</th>
#       <td id="T_fd227_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_fd227_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_fd227_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_fd227_row2_col3" class="data row2 col3" >2.34</td>
#     </tr>
#     <tr>
#       <th id="T_fd227_level0_row3" class="row_heading level0 row3" >2025-01-06 00:00:00</th>
#       <td id="T_fd227_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_fd227_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_fd227_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_fd227_row3_col3" class="data row3 col3" >2.34</td>
#     </tr>
#     <tr>
#       <th id="T_fd227_level0_row4" class="row_heading level0 row4" >2025-01-07 00:00:00</th>
#       <td id="T_fd227_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_fd227_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_fd227_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_fd227_row4_col3" class="data row4 col3" >2.38</td>
#     </tr>
#     <tr>
#       <th id="T_fd227_level0_row5" class="row_heading level0 row5" >2025-01-08 00:00:00</th>
#       <td id="T_fd227_row5_col0" class="data row5 col0" >nan</td>
#       <td id="T_fd227_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_fd227_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_fd227_row5_col3" class="data row5 col3" >2.40</td>
#     </tr>
#     <tr>
#       <th id="T_fd227_level0_row6" class="row_heading level0 row6" >2025-01-09 00:00:00</th>
#       <td id="T_fd227_row6_col0" class="data row6 col0" >nan</td>
#       <td id="T_fd227_row6_col1" class="data row6 col1" >nan</td>
#       <td id="T_fd227_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_fd227_row6_col3" class="data row6 col3" >2.39</td>
#     </tr>
#     <tr>
#       <th id="T_fd227_level0_row7" class="row_heading level0 row7" >2025-01-10 00:00:00</th>
#       <td id="T_fd227_row7_col0" class="data row7 col0" >nan</td>
#       <td id="T_fd227_row7_col1" class="data row7 col1" >nan</td>
#       <td id="T_fd227_row7_col2" class="data row7 col2" >nan</td>
#       <td id="T_fd227_row7_col3" class="data row7 col3" >2.43</td>
#     </tr>
#     <tr>
#       <th id="T_fd227_level0_row8" class="row_heading level0 row8" >2025-01-13 00:00:00</th>
#       <td id="T_fd227_row8_col0" class="data row8 col0" >nan</td>
#       <td id="T_fd227_row8_col1" class="data row8 col1" >nan</td>
#       <td id="T_fd227_row8_col2" class="data row8 col2" >nan</td>
#       <td id="T_fd227_row8_col3" class="data row8 col3" >2.45</td>
#     </tr>
#     <tr>
#       <th id="T_fd227_level0_row9" class="row_heading level0 row9" >2025-01-14 00:00:00</th>
#       <td id="T_fd227_row9_col0" class="data row9 col0" >nan</td>
#       <td id="T_fd227_row9_col1" class="data row9 col1" >nan</td>
#       <td id="T_fd227_row9_col2" class="data row9 col2" >nan</td>
#       <td id="T_fd227_row9_col3" class="data row9 col3" >2.44</td>
#     </tr>
#     <tr>
#       <th id="T_fd227_level0_row10" class="row_heading level0 row10" >2025-01-15 00:00:00</th>
#       <td id="T_fd227_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_fd227_row10_col1" class="data row10 col1" >nan</td>
#       <td id="T_fd227_row10_col2" class="data row10 col2" >nan</td>
#       <td id="T_fd227_row10_col3" class="data row10 col3" >2.42</td>
#     </tr>
#     <tr>
#       <th id="T_fd227_level0_row11" class="row_heading level0 row11" >2025-01-16 00:00:00</th>
#       <td id="T_fd227_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_fd227_row11_col1" class="data row11 col1" >nan</td>
#       <td id="T_fd227_row11_col2" class="data row11 col2" >nan</td>
#       <td id="T_fd227_row11_col3" class="data row11 col3" >2.42</td>
#     </tr>
#     <tr>
#       <th id="T_fd227_level0_row12" class="row_heading level0 row12" >2025-01-17 00:00:00</th>
#       <td id="T_fd227_row12_col0" class="data row12 col0" >nan</td>
#       <td id="T_fd227_row12_col1" class="data row12 col1" >nan</td>
#       <td id="T_fd227_row12_col2" class="data row12 col2" >nan</td>
#       <td id="T_fd227_row12_col3" class="data row12 col3" >2.41</td>
#     </tr>
#     <tr>
#       <th id="T_fd227_level0_row13" class="row_heading level0 row13" >2025-01-20 00:00:00</th>
#       <td id="T_fd227_row13_col0" class="data row13 col0" >nan</td>
#       <td id="T_fd227_row13_col1" class="data row13 col1" >nan</td>
#       <td id="T_fd227_row13_col2" class="data row13 col2" >nan</td>
#       <td id="T_fd227_row13_col3" class="data row13 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_fd227_level0_row14" class="row_heading level0 row14" >2025-01-21 00:00:00</th>
#       <td id="T_fd227_row14_col0" class="data row14 col0" >nan</td>
#       <td id="T_fd227_row14_col1" class="data row14 col1" >nan</td>
#       <td id="T_fd227_row14_col2" class="data row14 col2" >nan</td>
#       <td id="T_fd227_row14_col3" class="data row14 col3" >2.38</td>
#     </tr>
#     <tr>
#       <th id="T_fd227_level0_row15" class="row_heading level0 row15" >2025-01-22 00:00:00</th>
#       <td id="T_fd227_row15_col0" class="data row15 col0" >nan</td>
#       <td id="T_fd227_row15_col1" class="data row15 col1" >nan</td>
#       <td id="T_fd227_row15_col2" class="data row15 col2" >nan</td>
#       <td id="T_fd227_row15_col3" class="data row15 col3" >2.40</td>
#     </tr>
#     <tr>
#       <th id="T_fd227_level0_row16" class="row_heading level0 row16" >2025-01-23 00:00:00</th>
#       <td id="T_fd227_row16_col0" class="data row16 col0" >nan</td>
#       <td id="T_fd227_row16_col1" class="data row16 col1" >nan</td>
#       <td id="T_fd227_row16_col2" class="data row16 col2" >nan</td>
#       <td id="T_fd227_row16_col3" class="data row16 col3" >2.42</td>
#     </tr>
#     <tr>
#       <th id="T_fd227_level0_row17" class="row_heading level0 row17" >2025-01-24 00:00:00</th>
#       <td id="T_fd227_row17_col0" class="data row17 col0" >nan</td>
#       <td id="T_fd227_row17_col1" class="data row17 col1" >nan</td>
#       <td id="T_fd227_row17_col2" class="data row17 col2" >nan</td>
#       <td id="T_fd227_row17_col3" class="data row17 col3" >2.43</td>
#     </tr>
#     <tr>
#       <th id="T_fd227_level0_row18" class="row_heading level0 row18" >2025-01-27 00:00:00</th>
#       <td id="T_fd227_row18_col0" class="data row18 col0" >nan</td>
#       <td id="T_fd227_row18_col1" class="data row18 col1" >nan</td>
#       <td id="T_fd227_row18_col2" class="data row18 col2" >nan</td>
#       <td id="T_fd227_row18_col3" class="data row18 col3" >2.40</td>
#     </tr>
#     <tr>
#       <

# %%
fig = df.plot(title="FRED Data", width=1000, height=500)
fig.update_layout(hovermode="x unified")

# %% [markdown]
# ## Interpolate missing values

# %%
df = df.interpolate(method='linear')
df
# Out:
#                   CORESTICKM159SFRBATL  UNRATE  FEDFUNDS  T10YIE
# observation_date
# 1948-01-01                         NaN     3.4       NaN     NaN
# 1948-02-01                         NaN     3.8       NaN     NaN
# ...                                ...     ...       ...     ...
# 2025-04-10                    3.257815     4.2      4.33    2.19
# 2025-04-11                    3.257815     4.2      4.33    2.20
#
# [2189 rows x 4 columns]

# %%
fig = df.plot(title="FRED Data", width=1000, height=500)
fig.update_layout(hovermode="x unified")

# %% [markdown]
# ## Export data

# %%
df.to_parquet('../../data/FRED/FRED_joined.parquet')
