# %% [markdown]
# # [TITLE]

# %% [markdown]
# [URL]

# %% [markdown]
# ## Load data

# %%
PATH = "../../../data/EIA/fuel_type_data_california.parquet"

# %%
import pandas as pd
df = pd.read_parquet(PATH)

df
# Out:
#                           period respondent respondent-name fueltype  \
# 0      2025-04-22 20:00:00-07:00        CAL      California      BAT
# 1      2025-04-22 20:00:00-07:00        CAL      California      COL
# ...                          ...        ...             ...      ...
# 452546 2018-12-31 17:00:00-07:00        CAL      California      WAT
# 452547 2018-12-31 17:00:00-07:00        CAL      California      WND
#
#               type-name  value    value-units
# 0       Battery storage    179  megawatthours
# 1                  Coal    216  megawatthours
# ...                 ...    ...            ...
# 452546            Hydro   2880  megawatthours
# 452547             Wind   2628  megawatthours
#
# [452548 rows x 7 columns]

# %% [markdown]
# ## Preprocess data

# %% [markdown]
# ### Datetime column object

# %%
COLUMN_DATETIME = "period"

x = pd.to_datetime(df[COLUMN_DATETIME], utc=True)
x
# Out:
# 0        2025-04-23 03:00:00+00:00
# 1        2025-04-23 03:00:00+00:00
#                     ...
# 452546   2019-01-01 00:00:00+00:00
# 452547   2019-01-01 00:00:00+00:00
# Name: period, Length: 452548, dtype: datetime64[us, UTC]

# %%
df[COLUMN_DATETIME] = x

# %% [markdown]
# ### Local timezones

# %%
TIMEZONE = 'America/Los_Angeles'

x = df[COLUMN_DATETIME].dt.tz_convert(TIMEZONE)
x
# Out:
# 0        2025-04-22 20:00:00-07:00
# 1        2025-04-22 20:00:00-07:00
#                     ...
# 452546   2018-12-31 16:00:00-08:00
# 452547   2018-12-31 16:00:00-08:00
# Name: period, Length: 452548, dtype: datetime64[us, America/Los_Angeles]

# %%
df[COLUMN_DATETIME] = x

# %% [markdown]
# ### Available series inside dataset

# %%
COLUMN_CATEGORIES = ['respondent', 'respondent-name', 'fueltype', 'type-name']

df[COLUMN_CATEGORIES].drop_duplicates().style
# Out:
# <style type="text/css">
# </style>
# <table id="T_84380">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_84380_level0_col0" class="col_heading level0 col0" >respondent</th>
#       <th id="T_84380_level0_col1" class="col_heading level0 col1" >respondent-name</th>
#       <th id="T_84380_level0_col2" class="col_heading level0 col2" >fueltype</th>
#       <th id="T_84380_level0_col3" class="col_heading level0 col3" >type-name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84380_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_84380_row0_col0" class="data row0 col0" >CAL</td>
#       <td id="T_84380_row0_col1" class="data row0 col1" >California</td>
#       <td id="T_84380_row0_col2" class="data row0 col2" >BAT</td>
#       <td id="T_84380_row0_col3" class="data row0 col3" >Battery storage</td>
#     </tr>
#     <tr>
#       <th id="T_84380_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_84380_row1_col0" class="data row1 col0" >CAL</td>
#       <td id="T_84380_row1_col1" class="data row1 col1" >California</td>
#       <td id="T_84380_row1_col2" class="data row1 col2" >COL</td>
#       <td id="T_84380_row1_col3" class="data row1 col3" >Coal</td>
#     </tr>
#     <tr>
#       <th id="T_84380_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_84380_row2_col0" class="data row2 col0" >CAL</td>
#       <td id="T_84380_row2_col1" class="data row2 col1" >California</td>
#       <td id="T_84380_row2_col2" class="data row2 col2" >GEO</td>
#       <td id="T_84380_row2_col3" class="data row2 col3" >Geothermal</td>
#     </tr>
#     <tr>
#       <th id="T_84380_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_84380_row3_col0" class="data row3 col0" >CAL</td>
#       <td id="T_84380_row3_col1" class="data row3 col1" >California</td>
#       <td id="T_84380_row3_col2" class="data row3 col2" >NG</td>
#       <td id="T_84380_row3_col3" class="data row3 col3" >Natural Gas</td>
#     </tr>
#     <tr>
#       <th id="T_84380_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_84380_row4_col0" class="data row4 col0" >CAL</td>
#       <td id="T_84380_row4_col1" class="data row4 col1" >California</td>
#       <td id="T_84380_row4_col2" class="data row4 col2" >NUC</td>
#       <td id="T_84380_row4_col3" class="data row4 col3" >Nuclear</td>
#     </tr>
#     <tr>
#       <th id="T_84380_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_84380_row5_col0" class="data row5 col0" >CAL</td>
#       <td id="T_84380_row5_col1" class="data row5 col1" >California</td>
#       <td id="T_84380_row5_col2" class="data row5 col2" >OIL</td>
#       <td id="T_84380_row5_col3" class="data row5 col3" >Petroleum</td>
#     </tr>
#     <tr>
#       <th id="T_84380_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_84380_row6_col0" class="data row6 col0" >CAL</td>
#       <td id="T_84380_row6_col1" class="data row6 col1" >California</td>
#       <td id="T_84380_row6_col2" class="data row6 col2" >OTH</td>
#       <td id="T_84380_row6_col3" class="data row6 col3" >Other</td>
#     </tr>
#     <tr>
#       <th id="T_84380_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_84380_row7_col0" class="data row7 col0" >CAL</td>
#       <td id="T_84380_row7_col1" class="data row7 col1" >California</td>
#       <td id="T_84380_row7_col2" class="data row7 col2" >PS</td>
#       <td id="T_84380_row7_col3" class="data row7 col3" >Pumped storage</td>
#     </tr>
#     <tr>
#       <th id="T_84380_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_84380_row8_col0" class="data row8 col0" >CAL</td>
#       <td id="T_84380_row8_col1" class="data row8 col1" >California</td>
#       <td id="T_84380_row8_col2" class="data row8 col2" >SNB</td>
#       <td id="T_84380_row8_col3" class="data row8 col3" >Solar with integrated battery storage</td>
#     </tr>
#     <tr>
#       <th id="T_84380_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_84380_row9_col0" class="data row9 col0" >CAL</td>
#       <td id="T_84380_row9_col1" class="data row9 col1" >California</td>
#       <td id="T_84380_row9_col2" class="data row9 col2" >SUN</td>
#       <td id="T_84380_row9_col3" class="data row9 col3" >Solar</td>
#     </tr>
#     <tr>
#       <th id="T_84380_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_84380_row10_col0" class="data row10 col0" >CAL</td>
#       <td id="T_84380_row10_col1" class="data row10 col1" >California</td>
#       <td id="T_84380_row10_col2" class="data row10 col2" >WAT</td>
#       <td id="T_84380_row10_col3" class="data row10 col3" >Hydro</td>
#     </tr>
#     <tr>
#       <th id="T_84380_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_84380_row11_col0" class="data row11 col0" >CAL</td>
#       <td id="T_84380_row11_col1" class="data row11 col1" >California</td>
#       <td id="T_84380_row11_col2" class="data row11 col2" >WND</td>
#       <td id="T_84380_row11_col3" class="data row11 col3" >Wind</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Set index
#
# The index is composed by the columns that uniquely identify the rows. The datetime column must be present.

# %%
COLUMN_CATEGORIES = ['respondent-name', 'type-name']

idx = COLUMN_CATEGORIES + [COLUMN_DATETIME]
x = df.set_index(idx).sort_index()

x
# Out:
#                                                           respondent fueltype  \
# respondent-name type-name       period
# California      Battery storage 2025-01-01 01:00:00-08:00        CAL      BAT
#                                 2025-01-01 02:00:00-08:00        CAL      BAT
# ...                                                              ...      ...
#                 Wind            2025-04-22 19:00:00-07:00        CAL      WND
#                                 2025-04-22 20:00:00-07:00        CAL      WND
#
#                                                            value  \
# respondent-name type-name       period
# California      Battery storage 2025-01-01 01:00:00-08:00     11
#                                 2025-01-01 02:00:00-08:00     -1
# ...                                                          ...
#                 Wind            2025-04-22 19:00:00-07:00   3419
#                                 2025-04-22 20:00:00-07:00   3464
#
#                                                              value-units
# respondent-name type-name       period
# California      Battery storage 2025-01-01 01:00:00-08:00  megawatthours
#                                 2025-01-01 02:00:00-08:00  megawatthours
# ...                                                                  ...
#                 Wind            2025-04-22 19:00:00-07:00  megawatthours
#                                 2025-04-22 20:00:00-07:00  megawatthours
#
# [452548 rows x 4 columns]

# %%
x.index.is_unique
# Out:
# True

# %%
df = x.copy()

# %% [markdown]
# ### Select values column

# %%
COLUMN_VALUES = "value"

x = df[COLUMN_VALUES]
x
# Out:
# respondent-name  type-name        period
# California       Battery storage  2025-01-01 01:00:00-08:00      11
#                                   2025-01-01 02:00:00-08:00      -1
#                                                                ...
#                  Wind             2025-04-22 19:00:00-07:00    3419
#                                   2025-04-22 20:00:00-07:00    3464
# Name: value, Length: 452548, dtype: int64

# %%
plot = x.unstack(level=COLUMN_CATEGORIES).plot(figsize=(15, 8), linewidth=2, alpha=0.8)
plot.legend(loc="center left", bbox_to_anchor=(1, 0.5))
plot.figure.tight_layout()

# %%
series = x.copy()

# %% [markdown]
# ### Filter one time series
#
# To get a table with the unique datetime index of the series, and the time series values.
#
# <div class="alert alert-warning">
# Not necessary if the data already represents a time series with unique datetime values.
# </div>

# %%
CATEGORIES = ('California', 'Hydro')

x = series.loc[CATEGORIES]
x
# Out:
# period
# 2018-12-31 16:00:00-08:00    2880
# 2018-12-31 17:00:00-08:00    3979
#                              ...
# 2025-04-22 19:00:00-07:00    4159
# 2025-04-22 20:00:00-07:00    5334
# Name: value, Length: 55300, dtype: int64

# %%
from modules import utils
utils.configure_plotly_template(showlegend=True)

# %%
x.plot()

# %%
series = x.copy()

# %% [markdown]
# ### Filter datetime range
#
# <div class="alert alert-warning">
# Not necessary if you are interested in the whole time series. Although, it's advised to filter out outliers and incomplete data to get full periods, like full years, months, etc.
# </div>

# %%
START, END = '2021', '2024'

# %%
x = series.loc[START:END]
x
# Out:
# period
# 2021-01-01 00:00:00-08:00     983
# 2021-01-01 01:00:00-08:00     896
#                              ...
# 2024-12-31 22:00:00-08:00    4125
# 2024-12-31 23:00:00-08:00    3819
# Name: value, Length: 35064, dtype: int64

# %%
series = x.copy()

# %% [markdown]
# ### Aggregate

# %% [markdown]
# **Check if you need to aggregate your data:**
#
# - ✅ **Keep as-is** if data is already at appropriate frequency (monthly, quarterly, etc.)
# - 🔄 **Aggregate first** if data is too granular for your seasonal question:
#   - **Annual seasonality** → Aggregate to monthly
#   - **Weekly patterns** → Aggregate to daily
#   - **Daily patterns** → Aggregate to hourly
#
# **Rule of Thumb:**
#
# Match your data frequency to the seasonal cycle you want to study. Most seasonal business analysis works best with **monthly data** to capture yearly patterns.
#
# **Note**: You need at least 3-5 complete seasonal cycles for reliable decomposition results.

# %%
RULE = '1W'

# %%
x = series.resample(RULE).sum()
x.plot()

# %%
series = x.copy()

# %% [markdown]
# ### Additive model

# %%
import statsmodels.api as sm

# %%
PERIOD = 52

result = sm.tsa.seasonal_decompose(series, model='additive', period=PERIOD)

x = (x
 .to_frame()
 .assign(
    trend = result.trend,
    seasonal = result.seasonal,
    residual = result.resid)
 .dropna())

x
# Out:
#                             value          trend       seasonal      residual
# period
# 2021-07-04 00:00:00-07:00  387980  298263.153846   93165.471570  -3448.625416
# 2021-07-11 00:00:00-07:00  428251  301410.442308  118845.493205   7995.064488
# ...                           ...            ...            ...           ...
# 2024-06-30 00:00:00-07:00  617378  579598.423077   93165.471570 -55385.894647
# 2024-07-07 00:00:00-07:00  710933  576516.826923  118845.493205  15570.679872
#
# [158 rows x 4 columns]

# %%
x['model_result'] = x.trend + x.seasonal + x.residual
x
# Out:
#                             value          trend       seasonal      residual  \
# period
# 2021-07-04 00:00:00-07:00  387980  298263.153846   93165.471570  -3448.625416
# 2021-07-11 00:00:00-07:00  428251  301410.442308  118845.493205   7995.064488
# ...                           ...            ...            ...           ...
# 2024-06-30 00:00:00-07:00  617378  579598.423077   93165.471570 -55385.894647
# 2024-07-07 00:00:00-07:00  710933  576516.826923  118845.493205  15570.679872
#
#                            model_result
# period
# 2021-07-04 00:00:00-07:00      387980.0
# 2021-07-11 00:00:00-07:00      428251.0
# ...                                 ...
# 2024-06-30 00:00:00-07:00      617378.0
# 2024-07-07 00:00:00-07:00      710933.0
#
# [158 rows x 5 columns]

# %%
dfs = {}
dfs['additive'] = x

# %% [markdown]
# ### Multiplicative model

# %%
result = sm.tsa.seasonal_decompose(series, model='multiplicative', period=PERIOD)

x = (series
 .to_frame()
 .assign(
    trend = result.trend,
    seasonal = result.seasonal,
    residual = result.resid)
 .dropna())

x
# Out:
#                             value          trend  seasonal  residual
# period
# 2021-07-04 00:00:00-07:00  387980  298263.153846  1.215059  1.070564
# 2021-07-11 00:00:00-07:00  428251  301410.442308  1.270929  1.117940
# ...                           ...            ...       ...       ...
# 2024-06-30 00:00:00-07:00  617378  579598.423077  1.215059  0.876651
# 2024-07-07 00:00:00-07:00  710933  576516.826923  1.270929  0.970276
#
# [158 rows x 4 columns]

# %%
x['model_result'] = x.trend * x.seasonal * x.residual
x
# Out:
#                             value          trend  seasonal  residual  \
# period
# 2021-07-04 00:00:00-07:00  387980  298263.153846  1.215059  1.070564
# 2021-07-11 00:00:00-07:00  428251  301410.442308  1.270929  1.117940
# ...                           ...            ...       ...       ...
# 2024-06-30 00:00:00-07:00  617378  579598.423077  1.215059  0.876651
# 2024-07-07 00:00:00-07:00  710933  576516.826923  1.270929  0.970276
#
#                            model_result
# period
# 2021-07-04 00:00:00-07:00      387980.0
# 2021-07-11 00:00:00-07:00      428251.0
# ...                                 ...
# 2024-06-30 00:00:00-07:00      617378.0
# 2024-07-07 00:00:00-07:00      710933.0
#
# [158 rows x 5 columns]

# %%
dfs['multiplicative'] = x

# %% [markdown]
# ## Model comparison
#
# ### Numerical

# %%
df = pd.concat(dfs, axis=1).melt(ignore_index=False).reset_index()
df.columns = ["month", "model", "component", "value"]

# %%
df
# Out:
#                          month           model     component     value
# 0    2021-07-04 00:00:00-07:00        additive         value  387980.0
# 1    2021-07-11 00:00:00-07:00        additive         value  428251.0
# ...                        ...             ...           ...       ...
# 1578 2024-06-30 00:00:00-07:00  multiplicative  model_result  617378.0
# 1579 2024-07-07 00:00:00-07:00  multiplicative  model_result  710933.0
#
# [1580 rows x 4 columns]

# %% [markdown]
# ## Visual comparison

# %%
import plotly.express as px

fig = px.line(
    data_frame=df,
    x='month',
    y='value',
    color='component',
    facet_col='model',
    facet_row='component',
    width=1500,
    height=1000,
    facet_col_spacing=0.1,
)

fig.update_yaxes(matches=None)

for attr in dir(fig.layout):
    if attr.startswith("yaxis"):
        axis = getattr(fig.layout, attr)
        if axis:
            axis.showticklabels = True
        
fig

# %% [markdown]
# ## Ask AI to interpret the plot
