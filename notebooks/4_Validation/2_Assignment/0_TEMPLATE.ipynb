# %% [markdown]
# ## Load data

# %%
PATH = "../../../data/EIA/fuel_type_data_california.parquet"

# %%
import pandas as pd
df = pd.read_parquet(PATH)

df
# Out:
#                           period respondent respondent-name fueltype  \
# 0      2025-04-22 20:00:00-07:00        CAL      California      BAT
# 1      2025-04-22 20:00:00-07:00        CAL      California      COL
# ...                          ...        ...             ...      ...
# 452546 2018-12-31 17:00:00-07:00        CAL      California      WAT
# 452547 2018-12-31 17:00:00-07:00        CAL      California      WND
#
#               type-name  value    value-units
# 0       Battery storage    179  megawatthours
# 1                  Coal    216  megawatthours
# ...                 ...    ...            ...
# 452546            Hydro   2880  megawatthours
# 452547             Wind   2628  megawatthours
#
# [452548 rows x 7 columns]

# %% [markdown]
# ## Preprocess data

# %% [markdown]
# ### Datetime column object

# %%
COLUMN_DATETIME = "period"

x = pd.to_datetime(df[COLUMN_DATETIME], utc=True)
x
# Out:
# 0        2025-04-23 03:00:00+00:00
# 1        2025-04-23 03:00:00+00:00
#                     ...
# 452546   2019-01-01 00:00:00+00:00
# 452547   2019-01-01 00:00:00+00:00
# Name: period, Length: 452548, dtype: datetime64[us, UTC]

# %%
df[COLUMN_DATETIME] = x

# %% [markdown]
# ### Local timezones

# %%
TIMEZONE = 'America/Los_Angeles'

x = df[COLUMN_DATETIME]

try:
    x = x.dt.tz_convert(TIMEZONE)
except Exception as e:
    print(e)

x
# Out:
# 0        2025-04-22 20:00:00-07:00
# 1        2025-04-22 20:00:00-07:00
#                     ...
# 452546   2018-12-31 16:00:00-08:00
# 452547   2018-12-31 16:00:00-08:00
# Name: period, Length: 452548, dtype: datetime64[us, America/Los_Angeles]

# %%
df[COLUMN_DATETIME] = x

# %% [markdown]
# ### Available series inside dataset

# %%
COLUMN_CATEGORIES = ['respondent', 'respondent-name', 'fueltype', 'type-name']

df[COLUMN_CATEGORIES].drop_duplicates().style
# Out:
# <style type="text/css">
# </style>
# <table id="T_e5f05">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e5f05_level0_col0" class="col_heading level0 col0" >respondent</th>
#       <th id="T_e5f05_level0_col1" class="col_heading level0 col1" >respondent-name</th>
#       <th id="T_e5f05_level0_col2" class="col_heading level0 col2" >fueltype</th>
#       <th id="T_e5f05_level0_col3" class="col_heading level0 col3" >type-name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5f05_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e5f05_row0_col0" class="data row0 col0" >CAL</td>
#       <td id="T_e5f05_row0_col1" class="data row0 col1" >California</td>
#       <td id="T_e5f05_row0_col2" class="data row0 col2" >BAT</td>
#       <td id="T_e5f05_row0_col3" class="data row0 col3" >Battery storage</td>
#     </tr>
#     <tr>
#       <th id="T_e5f05_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e5f05_row1_col0" class="data row1 col0" >CAL</td>
#       <td id="T_e5f05_row1_col1" class="data row1 col1" >California</td>
#       <td id="T_e5f05_row1_col2" class="data row1 col2" >COL</td>
#       <td id="T_e5f05_row1_col3" class="data row1 col3" >Coal</td>
#     </tr>
#     <tr>
#       <th id="T_e5f05_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e5f05_row2_col0" class="data row2 col0" >CAL</td>
#       <td id="T_e5f05_row2_col1" class="data row2 col1" >California</td>
#       <td id="T_e5f05_row2_col2" class="data row2 col2" >GEO</td>
#       <td id="T_e5f05_row2_col3" class="data row2 col3" >Geothermal</td>
#     </tr>
#     <tr>
#       <th id="T_e5f05_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e5f05_row3_col0" class="data row3 col0" >CAL</td>
#       <td id="T_e5f05_row3_col1" class="data row3 col1" >California</td>
#       <td id="T_e5f05_row3_col2" class="data row3 col2" >NG</td>
#       <td id="T_e5f05_row3_col3" class="data row3 col3" >Natural Gas</td>
#     </tr>
#     <tr>
#       <th id="T_e5f05_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e5f05_row4_col0" class="data row4 col0" >CAL</td>
#       <td id="T_e5f05_row4_col1" class="data row4 col1" >California</td>
#       <td id="T_e5f05_row4_col2" class="data row4 col2" >NUC</td>
#       <td id="T_e5f05_row4_col3" class="data row4 col3" >Nuclear</td>
#     </tr>
#     <tr>
#       <th id="T_e5f05_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e5f05_row5_col0" class="data row5 col0" >CAL</td>
#       <td id="T_e5f05_row5_col1" class="data row5 col1" >California</td>
#       <td id="T_e5f05_row5_col2" class="data row5 col2" >OIL</td>
#       <td id="T_e5f05_row5_col3" class="data row5 col3" >Petroleum</td>
#     </tr>
#     <tr>
#       <th id="T_e5f05_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e5f05_row6_col0" class="data row6 col0" >CAL</td>
#       <td id="T_e5f05_row6_col1" class="data row6 col1" >California</td>
#       <td id="T_e5f05_row6_col2" class="data row6 col2" >OTH</td>
#       <td id="T_e5f05_row6_col3" class="data row6 col3" >Other</td>
#     </tr>
#     <tr>
#       <th id="T_e5f05_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e5f05_row7_col0" class="data row7 col0" >CAL</td>
#       <td id="T_e5f05_row7_col1" class="data row7 col1" >California</td>
#       <td id="T_e5f05_row7_col2" class="data row7 col2" >PS</td>
#       <td id="T_e5f05_row7_col3" class="data row7 col3" >Pumped storage</td>
#     </tr>
#     <tr>
#       <th id="T_e5f05_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e5f05_row8_col0" class="data row8 col0" >CAL</td>
#       <td id="T_e5f05_row8_col1" class="data row8 col1" >California</td>
#       <td id="T_e5f05_row8_col2" class="data row8 col2" >SNB</td>
#       <td id="T_e5f05_row8_col3" class="data row8 col3" >Solar with integrated battery storage</td>
#     </tr>
#     <tr>
#       <th id="T_e5f05_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e5f05_row9_col0" class="data row9 col0" >CAL</td>
#       <td id="T_e5f05_row9_col1" class="data row9 col1" >California</td>
#       <td id="T_e5f05_row9_col2" class="data row9 col2" >SUN</td>
#       <td id="T_e5f05_row9_col3" class="data row9 col3" >Solar</td>
#     </tr>
#     <tr>
#       <th id="T_e5f05_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e5f05_row10_col0" class="data row10 col0" >CAL</td>
#       <td id="T_e5f05_row10_col1" class="data row10 col1" >California</td>
#       <td id="T_e5f05_row10_col2" class="data row10 col2" >WAT</td>
#       <td id="T_e5f05_row10_col3" class="data row10 col3" >Hydro</td>
#     </tr>
#     <tr>
#       <th id="T_e5f05_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e5f05_row11_col0" class="data row11 col0" >CAL</td>
#       <td id="T_e5f05_row11_col1" class="data row11 col1" >California</td>
#       <td id="T_e5f05_row11_col2" class="data row11 col2" >WND</td>
#       <td id="T_e5f05_row11_col3" class="data row11 col3" >Wind</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Set index
#
# The index is composed by the columns that uniquely identify the rows. The datetime column must be present.

# %%
COLUMN_CATEGORIES = ['respondent-name', 'type-name']

idx = COLUMN_CATEGORIES + [COLUMN_DATETIME]
x = df.set_index(idx).sort_index()

x
# Out:
#                                                           respondent fueltype  \
# respondent-name type-name       period
# California      Battery storage 2025-01-01 01:00:00-08:00        CAL      BAT
#                                 2025-01-01 02:00:00-08:00        CAL      BAT
# ...                                                              ...      ...
#                 Wind            2025-04-22 19:00:00-07:00        CAL      WND
#                                 2025-04-22 20:00:00-07:00        CAL      WND
#
#                                                            value  \
# respondent-name type-name       period
# California      Battery storage 2025-01-01 01:00:00-08:00     11
#                                 2025-01-01 02:00:00-08:00     -1
# ...                                                          ...
#                 Wind            2025-04-22 19:00:00-07:00   3419
#                                 2025-04-22 20:00:00-07:00   3464
#
#                                                              value-units
# respondent-name type-name       period
# California      Battery storage 2025-01-01 01:00:00-08:00  megawatthours
#                                 2025-01-01 02:00:00-08:00  megawatthours
# ...                                                                  ...
#                 Wind            2025-04-22 19:00:00-07:00  megawatthours
#                                 2025-04-22 20:00:00-07:00  megawatthours
#
# [452548 rows x 4 columns]

# %%
x.index.is_unique
# Out:
# True

# %%
df = x.copy()

# %% [markdown]
# ### Select values column

# %%
COLUMN_VALUES = "value"

x = df[COLUMN_VALUES]
x
# Out:
# respondent-name  type-name        period
# California       Battery storage  2025-01-01 01:00:00-08:00      11
#                                   2025-01-01 02:00:00-08:00      -1
#                                                                ...
#                  Wind             2025-04-22 19:00:00-07:00    3419
#                                   2025-04-22 20:00:00-07:00    3464
# Name: value, Length: 452548, dtype: int64

# %% [markdown]
# plot = x.unstack(level=COLUMN_CATEGORIES).plot(figsize=(15, 8), linewidth=2, alpha=0.8)
# plot.legend(loc="center left", bbox_to_anchor=(1, 0.5))
# plot.figure.tight_layout()

# %%
series = x.copy()

# %% [markdown]
# ### Filter one time series
#
# To get a table with the unique datetime index of the series, and the time series values.
#
# <div class="alert alert-warning">
# Not necessary if the data already represents a time series with unique datetime values.
# </div>

# %%
CATEGORIES = ('California', 'Solar')

x = series.loc[CATEGORIES]
x
# Out:
# period
# 2018-12-31 16:00:00-08:00     1595
# 2018-12-31 17:00:00-08:00        8
#                              ...
# 2025-04-22 19:00:00-07:00    13293
# 2025-04-22 20:00:00-07:00     5113
# Name: value, Length: 55300, dtype: int64

# %%
from modules import utils
utils.configure_plotly_template(showlegend=True)

# %%
x.plot()

# %%
series = x.copy()

# %% [markdown]
# ### Aggregate

# %% [markdown]
# **Check if you need to aggregate your data:**
#
# - ✅ **Keep as-is** if data is already at appropriate frequency (monthly, quarterly, etc.)
# - 🔄 **Aggregate first** if data is too granular for your seasonal question:
#   - **Annual seasonality** → Aggregate to monthly
#   - **Weekly patterns** → Aggregate to daily
#   - **Daily patterns** → Aggregate to hourly
#
# **Rule of Thumb:**
#
# Match your data frequency to the seasonal cycle you want to study. Most seasonal business analysis works best with **monthly data** to capture yearly patterns.
#
# **Note**: You need at least 3-5 complete seasonal cycles for reliable decomposition results.

# %%
RULE = 'W-MON'

x = series.resample(RULE).sum()
x
# Out:
# period
# 2018-12-31 00:00:00-08:00       1470
# 2019-01-07 00:00:00-08:00     365092
#                               ...
# 2025-04-21 00:00:00-07:00    1196278
# 2025-04-28 00:00:00-07:00     195256
# Freq: W-MON, Name: value, Length: 331, dtype: int64

# %%
x.plot()

# %%
series = x.copy()

# %% [markdown]
# ### Transform datetime index to standard format

# %%
x.index = x.index.tz_localize(None).astype("datetime64[ns]")
x.index.freq = RULE
x
# Out:
# period
# 2018-12-31       1470
# 2019-01-07     365092
#                ...
# 2025-04-21    1196278
# 2025-04-28     195256
# Freq: W-MON, Name: value, Length: 331, dtype: int64

# %%
series = x.copy()

# %% [markdown]
# ### Filter datetime range
#
# <div class="alert alert-warning">
# Not necessary if you are interested in the whole time series. Although, it's advised to filter out outliers and incomplete data to get full periods, like full years, months, etc.
# </div>

# %%
START, END = '2020', '2024'

# %%
x = series.loc[START:END]
x
# Out:
# period
# 2020-01-06    398621
# 2020-01-13    386968
#                ...
# 2024-12-23    570129
# 2024-12-30    547226
# Freq: W-MON, Name: value, Length: 261, dtype: int64

# %%
x.plot()

# %%
series = x.copy()
df = series.to_frame(name='values')

df
# Out:
#             values
# period
# 2020-01-06  398621
# 2020-01-13  386968
# ...            ...
# 2024-12-23  570129
# 2024-12-30  547226
#
# [261 rows x 1 columns]

# %% [markdown]
# ## Data stationarity

# %% [markdown]
# #### Constant variance

# %%
from statsmodels.tsa.stattools import adfuller
adfuller(df["values"])
# Out:
# (np.float64(-5.275907610299082),
#  np.float64(6.14123246007302e-06),
#  12,
#  248,
#  {'1%': np.float64(-3.4569962781990573),
#   '5%': np.float64(-2.8732659015936024),
#   '10%': np.float64(-2.573018897632674)},
#  np.float64(6230.896470408243))

# %%
import numpy as np

df["values_log"] = np.log(df["values"])
df = df.dropna()
df
# Out:
#             values  values_log
# period
# 2020-01-06  398621   12.895766
# 2020-01-13  386968   12.866097
# ...            ...         ...
# 2024-12-23  570129   13.253618
# 2024-12-30  547226   13.212617
#
# [261 rows x 2 columns]

# %%
adfuller(df["values_log"])
# Out:
# (np.float64(-5.261322686947487),
#  np.float64(6.5816023792774525e-06),
#  13,
#  247,
#  {'1%': np.float64(-3.457105309726321),
#   '5%': np.float64(-2.873313676101283),
#   '10%': np.float64(-2.5730443824681606)},
#  np.float64(-282.53049920814556))

# %%
fig = df.plot(facet_col="variable")
fig.update_yaxes(matches=None)
fig.update_layout()

# %%
PERIODS = 52

utils.plot_decomposition_comparison(df["values_log"], period=PERIODS)

# %% [markdown]
# #### Constant mean

# %%
df['values_log_diff'] = df['values_log'].diff().dropna()
df
# Out:
#             values  values_log  values_log_diff
# period
# 2020-01-06  398621   12.895766              NaN
# 2020-01-13  386968   12.866097        -0.029669
# ...            ...         ...              ...
# 2024-12-23  570129   13.253618        -0.020987
# 2024-12-30  547226   13.212617        -0.041001
#
# [261 rows x 3 columns]

# %%
df = df.dropna()
df
# Out:
#             values  values_log  values_log_diff
# period
# 2020-01-13  386968   12.866097        -0.029669
# 2020-01-20  342596   12.744307        -0.121790
# ...            ...         ...              ...
# 2024-12-23  570129   13.253618        -0.020987
# 2024-12-30  547226   13.212617        -0.041001
#
# [260 rows x 3 columns]

# %%
fig = df.plot(facet_col="variable")
fig.update_yaxes(matches=None)
fig.update_layout()

# %%
adfuller(df["values_log_diff"])
# Out:
# (np.float64(-22.51237514524953),
#  0.0,
#  0,
#  259,
#  {'1%': np.float64(-3.4558530692911504),
#   '5%': np.float64(-2.872764881778665),
#   '10%': np.float64(-2.572751643088207)},
#  np.float64(-271.622491817428))

# %% [markdown]
# ## ACF & PACF

# %%
COLUMN_VALUES = "values_log_diff"

# %%
x = df[COLUMN_VALUES]
x
# Out:
# period
# 2020-01-13   -0.029669
# 2020-01-20   -0.121790
#                 ...
# 2024-12-23   -0.020987
# 2024-12-30   -0.041001
# Freq: W-MON, Name: values_log_diff, Length: 260, dtype: float64

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt

# %%
LAGS = 2.1 * PERIODS

fig, axes = plt.subplots(2, 1, figsize=(10, 6))

plot_acf(x, ax=axes[0], lags=LAGS)
axes[0].set_title("ACF of log-differenced series")

plot_pacf(x, ax=axes[1], lags=LAGS)
axes[1].set_title("PACF of log-differenced series")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Train test split

# %%
TEST_SIZE = PERIODS # 1 year

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(series, test_size=TEST_SIZE, shuffle=False)

# %% [markdown]
# ## Variation playground

# %% [markdown]
# ### Experiment configuration

# %%
from modules.utils import TimeSeriesForecaster

# %%
p, d, q = order = (0, 1, 1)
P, D, Q, s = seasonal_order = (0, 1, 1, PERIODS)

CONFIGS = {
    "sarima": {
        "model_params": {
            "order": order,
            "seasonal_order": seasonal_order,
            "enforce_invertibility": False,
            "enforce_stationarity": False,
        },
        "log_transform": True,
    },
    "ets": {
        "model_params": {
            "trend": "add",
            "seasonal": "mul",
            "damped_trend": False,
        },
        "log_transform": True,
    },
    "prophet": {
        "model_params": {
            "seasonality_mode": "multiplicative",
            "yearly_seasonality": True,
            "weekly_seasonality": False,
            "daily_seasonality": False,
            "changepoint_prior_scale": 0.5,
            'seasonality_prior_scale': 15.0,
        },
        "log_transform": True,
    },
}

# %%
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

METRICS = {
    'rmse': root_mean_squared_error,
    'mae': mean_absolute_error,
    'mape': mean_absolute_percentage_error,
}

# %% [markdown]
# ### Run experiment with all models

# %%
RULE = 'W-MON'

# %%
from modules.utils import TimeSeriesForecaster

idx_offset = d + D * s

tf = TimeSeriesForecaster(train=train, test=test, freq=RULE, idx_offset=idx_offset)
df_forecast = tf.bulk_forecast(CONFIGS, metrics=METRICS)
df_forecast
# Out:
# /Users/sota/miniforge3/envs/time-series/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning:
#
# Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
# 21:14:06 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:06 - cmdstanpy - INFO - Chain [1] done processing
#       model  split                                             values  \
# 0    sarima  train  [431903.85249031254, 405452.95704784495, 52232...
# 1    sarima   test  [547643.6606061577, 491225.116678997, 630536.0...
# ..      ...    ...                                                ...
# 4   prophet  train  [393574.68493092863, 425038.612339741, 468065....
# 5   prophet   test  [483083.54313398665, 515087.0247251054, 562101...
#
#                                              datetime           rmse  \
# 0   DatetimeIndex(['2021-01-11', '2021-01-18', '20...  101040.814892
# 1   DatetimeIndex(['2024-01-08', '2024-01-15', '20...  106180.434893
# ..                                                ...            ...
# 4   DatetimeIndex(['2021-01-11', '2021-01-18', '20...   62661.648659
# 5   DatetimeIndex(['2024-01-08', '2024-01-15', '20...  160068.266678
#
#               mae      mape
# 0    82272.223858  0.119526
# 1    82940.035473  0.106387
# ..            ...       ...
# 4    51180.260700  0.077818
# 5   138034.612106  0.161744
#
# [6 rows x 7 columns]

# %% [markdown]
# ## Choose best model

# %% [markdown]
# ### Forecast plot

# %%
df_combined = tf.combine_with_historical(df_forecast)
df_combined
# Out:
#           model split   datetime         values
# 0           ets  test 2024-01-08  537729.163099
# 1           ets  test 2024-01-15  483105.055991
# ..          ...   ...        ...            ...
# 830  historical  test 2024-12-23         570129
# 831  historical  test 2024-12-30         547226
#
# [832 rows x 4 columns]

# %%
import plotly.express as px

fig = px.line(
    data_frame=df_combined,
    x='datetime',
    y='values',
    color='model',
    facet_col='split',
    category_orders={'split': ['train', 'test']}
)

fig.update_xaxes(matches=None)

# %% [markdown]
# ### Metrics review

# %%
dfm = df_forecast.melt(id_vars=["split", "model"], value_vars=["rmse", "mae", "mape"])
dfp = dfm.pivot(index=["split", "model"], columns="variable", values="value")
dfp.style.background_gradient(cmap="Greens_r", axis=0).format(precision=2)
# Out:
# <style type="text/css">
# #T_7bb6a_row0_col0 {
#   background-color: #42ab5d;
#   color: #f1f1f1;
# }
# #T_7bb6a_row0_col1 {
#   background-color: #349d53;
#   color: #f1f1f1;
# }
# #T_7bb6a_row0_col2, #T_7bb6a_row2_col2 {
#   background-color: #5eb96b;
#   color: #f1f1f1;
# }
# #T_7bb6a_row1_col0, #T_7bb6a_row1_col1, #T_7bb6a_row1_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_7bb6a_row2_col0 {
#   background-color: #3fa85b;
#   color: #f1f1f1;
# }
# #T_7bb6a_row2_col1 {
#   background-color: #39a257;
#   color: #f1f1f1;
# }
# #T_7bb6a_row3_col0 {
#   background-color: #005924;
#   color: #f1f1f1;
# }
# #T_7bb6a_row3_col1, #T_7bb6a_row3_col2 {
#   background-color: #005a24;
#   color: #f1f1f1;
# }
# #T_7bb6a_row4_col0, #T_7bb6a_row4_col1, #T_7bb6a_row4_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_7bb6a_row5_col0 {
#   background-color: #3da65a;
#   color: #f1f1f1;
# }
# #T_7bb6a_row5_col1 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_7bb6a_row5_col2 {
#   background-color: #48ae60;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7bb6a">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >variable</th>
#       <th id="T_7bb6a_level0_col0" class="col_heading level0 col0" >mae</th>
#       <th id="T_7bb6a_level0_col1" class="col_heading level0 col1" >mape</th>
#       <th id="T_7bb6a_level0_col2" class="col_heading level0 col2" >rmse</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >split</th>
#       <th class="index_name level1" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7bb6a_level0_row0" class="row_heading level0 row0" rowspan="3">test</th>
#       <th id="T_7bb6a_level1_row0" class="row_heading level1 row0" >ets</th>
#       <td id="T_7bb6a_row0_col0" class="data row0 col0" >83902.36</td>
#       <td id="T_7bb6a_row0_col1" class="data row0 col1" >0.10</td>
#       <td id="T_7bb6a_row0_col2" class="data row0 col2" >106094.26</td>
#     </tr>
#     <tr>
#       <th id="T_7bb6a_level1_row1" class="row_heading level1 row1" >prophet</th>
#       <td id="T_7bb6a_row1_col0" class="data row1 col0" >138034.61</td>
#       <td id="T_7bb6a_row1_col1" class="data row1 col1" >0.16</td>
#       <td id="T_7bb6a_row1_col2" class="data row1 col2" >160068.27</td>
#     </tr>
#     <tr>
#       <th id="T_7bb6a_level1_row2" class="row_heading level1 row2" >sarima</th>
#       <td id="T_7bb6a_row2_col0" class="data row2 col0" >82940.04</td>
#       <td id="T_7bb6a_row2_col1" class="data row2 col1" >0.11</td>
#       <td id="T_7bb6a_row2_col2" class="data row2 col2" >106180.43</td>
#     </tr>
#     <tr>
#       <th id="T_7bb6a_level0_row3" class="row_heading level0 row3" rowspan="3">train</th>
#       <th id="T_7bb6a_level1_row3" class="row_heading level1 row3" >ets</th>
#       <td id="T_7bb6a_row3_col0" class="data row3 col0" >56774.73</td>
#       <td id="T_7bb6a_row3_col1" class="data row3 col1" >0.08</td>
#       <td id="T_7bb6a_row3_col2" class="data row3 col2" >69464.64</td>
#     </tr>
#     <tr>
#       <th id="T_7bb6a_level1_row4" class="row_heading level1 row4" >prophet</th>
#       <td id="T_7bb6a_row4_col0" class="data row4 col0" >51180.26</td>
#       <td id="T_7bb6a_row4_col1" class="data row4 col1" >0.08</td>
#       <td id="T_7bb6a_row4_col2" class="data row4 col2" >62661.65</td>
#     </tr>
#     <tr>
#       <th id="T_7bb6a_level1_row5" class="row_heading level1 row5" >sarima</th>
#       <td id="T_7bb6a_row5_col0" class="data row5 col0" >82272.22</td>
#       <td id="T_7bb6a_row5_col1" class="data row5 col1" >0.12</td>
#       <td id="T_7bb6a_row5_col2" class="data row5 col2" >101040.81</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Diagnostics to validate assumptions

# %% [markdown]
# ### Model fit

# %%
x = df["values"]
x
# Out:
# period
# 2020-01-13    386968
# 2020-01-20    342596
#                ...
# 2024-12-23    570129
# 2024-12-30    547226
# Freq: W-MON, Name: values, Length: 260, dtype: int64

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

p, d, q = order = (0, 1, 1)
P, D, Q, s = seasonal_order = (0, 1, 1, 12)

model = SARIMAX(x, order=order, seasonal_order=seasonal_order)
model_fit = model.fit()

# %% [markdown]
# ### Residuals

# %%
idx_offset = d + D * s

residuals = model_fit.resid[idx_offset:]
residuals
# Out:
# period
# 2020-04-13   -103486.233572
# 2020-04-20    100765.384252
#                   ...
# 2024-12-23    -32863.952065
# 2024-12-30     14057.273004
# Freq: W-MON, Length: 247, dtype: float64

# %% [markdown]
# ### Assumptions
# #### Autocorrelation

# %% [markdown]
# ##### Plot

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(residuals);

# %% [markdown]
# ##### Test

# %%
from statsmodels.stats.diagnostic import acorr_ljungbox

acorr_ljungbox(residuals, lags=[10, 20, 30]).style
# Out:
# <style type="text/css">
# </style>
# <table id="T_7fddd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7fddd_level0_col0" class="col_heading level0 col0" >lb_stat</th>
#       <th id="T_7fddd_level0_col1" class="col_heading level0 col1" >lb_pvalue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7fddd_level0_row0" class="row_heading level0 row0" >10</th>
#       <td id="T_7fddd_row0_col0" class="data row0 col0" >21.511992</td>
#       <td id="T_7fddd_row0_col1" class="data row0 col1" >0.017793</td>
#     </tr>
#     <tr>
#       <th id="T_7fddd_level0_row1" class="row_heading level0 row1" >20</th>
#       <td id="T_7fddd_row1_col0" class="data row1 col0" >33.746893</td>
#       <td id="T_7fddd_row1_col1" class="data row1 col1" >0.027889</td>
#     </tr>
#     <tr>
#       <th id="T_7fddd_level0_row2" class="row_heading level0 row2" >30</th>
#       <td id="T_7fddd_row2_col0" class="data row2 col0" >85.281139</td>
#       <td id="T_7fddd_row2_col1" class="data row2 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Normality

# %% [markdown]
# ##### Plot

# %%
import matplotlib.pyplot as plt
from scipy import stats

fig, ax = plt.subplots()
stats.probplot(residuals, dist='norm', plot=ax);

# %% [markdown]
# ##### Test

# %%
from scipy.stats import jarque_bera
jarque_bera(residuals)
# Out:
# SignificanceResult(statistic=np.float64(0.44609571015593924), pvalue=np.float64(0.8000765606522168))

# %% [markdown]
# #### Homoscedasticity

# %% [markdown]
# ##### Plot

# %%
residuals.plot()

# %% [markdown]
# ##### Test

# %%
from statsmodels.stats.diagnostic import het_arch
het_arch(residuals)
# Out:
# (np.float64(6.140415773408308),
#  np.float64(0.8033313247296926),
#  0.6011160287927233,
#  0.8121516308772259)
